# %% [markdown]
# Election de 2022 premier tour

# %%
import numpy as np
import pandas as pd
import os
os.listdir()
# Out:
# ['migrations',
#  'election2017.ipynb',
#  '.DS_Store',
#  'alembic.ini',
#  'economie_chomage.ipynb',
#  'economie',
#  'menage_epargne.ipynb',
#  'enums',
#  'utils',
#  'models',
#  'election2012.ipynb',
#  'exports',
#  'labo1.ipynb',
#  '.gitignore',
#  'population.ipynb',
#  'scripts',
#  'db',
#  'securite.ipynb',
#  'chomages',
#  'labo2.ipynb',
#  'population_immigration.ipynb',
#  '.git',
#  'main.py',
#  'election2022.ipynb',
#  'data',
#  'menage_depense.ipynb']

# %% [markdown]
# #### Importer la database

# %% [markdown]
# Import des datasets.

# %%
df = pd.read_excel('./data/economie/menage/epargne.xlsx')

# %% [markdown]
# Visualise toutes les colones

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

df.head(1000)
# Out:
#     Année  Taux d'épargne
# 0    1960            17.0
# 1    1961            16.2
# 2    1962            18.3
# 3    1963            17.8
# 4    1964            17.6
# ..    ...             ...
# 58   2018            14.4
# 59   2019            15.1
# 60   2020            20.9
# 61   2021            19.0
# 62   2022            17.4
#
# [63 rows x 2 columns]

# %% [markdown]
# Renommer les colonnes

# %%
df.columns = [
    "annee", "taux_epargne"
]
df.head()
# Out:
#    annee  taux_epargne
# 0   1960          17.0
# 1   1961          16.2
# 2   1962          18.3
# 3   1963          17.8
# 4   1964          17.6

# %% [markdown]
# Normalisation structurelle

# %%
# Conversion de l'année en int

df["annee"] = (
    df["annee"]
    .astype(str)
    .str.extract(r"(\d{4})")[0]  # sécurité si texte parasite
    .astype(int)
)


# Conversion des pourcentages en float

colonnes_pourcentage = [
    "taux_epargne",
]

for col in colonnes_pourcentage:
    df[col] = (
        df[col]
        .astype(str)
        .str.replace("%", "", regex=False)
        .str.replace(",", ".", regex=False)
        .str.strip()
        .astype(float)
    )

# %%
df = df[(df["annee"] >= 2007) & (df["annee"] <= 2022)]

# %%
df.head(16)
# Out:
#     annee  taux_epargne
# 47   2007          14.8
# 48   2008          14.8
# 49   2009          16.1
# 50   2010          16.0
# 51   2011          15.6
# 52   2012          15.6
# 53   2013          14.2
# 54   2014          14.6
# 55   2015          14.1
# 56   2016          13.9
# 57   2017          14.1
# 58   2018          14.4
# 59   2019          15.1
# 60   2020          20.9
# 61   2021          19.0
# 62   2022          17.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 47 to 62
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   annee         16 non-null     int64
#  1   taux_epargne  16 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 384.0 bytes

# %%
from db import SessionLocal
from models import MenageEpargne

# Création d'une session
session = SessionLocal()

# Insertion des données du DataFrame
for row in df.itertuples(index=False):
    record = MenageEpargne(
        annee=row.annee,
        taux_epargne=row.taux_epargne
    )
    session.add(record)

# Validation / commit
session.commit()

print(f"Insertion terminée pour les années {df['annee'].min()} à {df['annee'].max()}.")
# Out:
# 2026-01-08 06:45:23,991 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2026-01-08 06:45:23,992 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-01-08 06:45:23,997 INFO sqlalchemy.engine.Engine select current_schema()
# 2026-01-08 06:45:23,997 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-01-08 06:45:23,998 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2026-01-08 06:45:23,999 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-01-08 06:45:24,000 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-01-08 06:45:24,003 INFO sqlalchemy.engine.Engine INSERT INTO menage_depenses (annee, pre_engagees, logement, service_multimedia) SELECT p0::INTEGER, p1::FLOAT, p2::FLOAT, p3::FLOAT FROM (VALUES (%(annee__0)s, %(pre_engagees__0)s, %(logement__0)s, %(service_multimedia__0)s, 0), (%(annee__1)s, %(pre_ ... 1287 characters truncated ...  p2, p3, sen_counter) ORDER BY sen_counter RETURNING menage_depenses.id, menage_depenses.id AS id__1
# ...
