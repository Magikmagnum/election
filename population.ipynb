# %% [markdown]
# Election de 2022 premier tour

# %%
import numpy as np
import pandas as pd
import os
os.listdir()
# Out:
# ['pipeline',
#  'elec17.py',
#  'migrations',
#  'election2017.ipynb',
#  'elec22.py',
#  'entreprise.ipynb',
#  '.DS_Store',
#  'elec12.py',
#  'alembic.ini',
#  'economie_chomage.ipynb',
#  'enums',
#  'utils',
#  'models',
#  'election2012.ipynb',
#  'exports',
#  'labo1.ipynb',
#  'menage.ipynb',
#  '.gitignore',
#  'population.ipynb',
#  'scripts',
#  'db',
#  'securite.ipynb',
#  'labo2.ipynb',
#  'population_immigration.ipynb',
#  '.git',
#  'main.py',
#  'election2022.ipynb',
#  'data']

# %% [markdown]
# #### Importer la database

# %% [markdown]
# Import des datasets.

# %%
df = pd.read_excel('./data/populations/pop-2007.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 df = pd.read_excel('./data/populations/pop-2007.xlsx')
#
# File /usr/local/lib/python3.11/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File /usr/local/lib/python3.11/site-packages/pandas/io/excel/_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File /usr/local/lib/python3.11/site-packages/pandas/io/excel/_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File /usr/local/lib/python3.11/site-packages/pandas/io/common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/populations/pop-2007.xlsx'

# %% [markdown]
# Visualise toutes les colones

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

df.head(1000)
# Out:
#     Départements               Unnamed: 1    Ensemble   Unnamed: 3  \
# 0            NaN                      NaN  0 à 19 ans  20 à 39 ans
# 1             01                      Ain      153719       147284
# 2             02                    Aisne      141079       131304
# 3             03                   Allier       71446        74685
# 4             04  Alpes-de-Haute-Provence       35905        32707
# ..           ...                      ...         ...          ...
# 96            95               Val-d'Oise      336059       328308
# 97           971              Guadeloupe       122977        98651
# 98           972              Martinique       113813        97129
# 99           973                   Guyane       94722        63937
# 100          974               La Réunion      278190       227692
#
#       Unnamed: 4   Unnamed: 5      Unnamed: 6 Unnamed: 7      Hommes  \
# 0    40 à 59 ans  60 à 74 ans  75 ans et plus      Total  0 à 19 ans
# 1         163003        68837           41534     574377       78672
# 2         152341        67757           45339     537820       72302
# 3          97923        56218           42842     343114       36753
# 4          45416        25895           16144     156067       18655
# ..           ...          ...             ...        ...         ...
# 96        323309       112904           60141    1160721      172309
# 97        110972        45406           22578     400584       63118
# 98        113223        48495           25070     397730       57391
# 99         41967         9220            3185     213031       47623
# 100       200272        63748           24205     794107      141874
#
#       Unnamed: 9  Unnamed: 10  Unnamed: 11     Unnamed: 12 Unnamed: 13  \
# 0    20 à 39 ans  40 à 59 ans  60 à 74 ans  75 ans et plus       Total
# 1          74187        81771        33496           15625      283751
# 2          65638        76034        31402           16208      261584
# 3          37614        48399        25918           15787      164471
# 4          15991        22354        12322            6247       75569
# ..           ...          ...          ...             ...         ...
# 96        160395       156871        54232           21198      565005
# 97         44730        51025        20686            8766      188325
# 98         44191        51680        22116            9592      184970
# 99         30538        21381         4720            1284      105546
# 100       107793        97687        29243            8738      385335
#
#          Femmes  Unnamed: 15  Unnamed: 16  Unnamed: 17     Unnamed: 18  \
# 0    0 à 19 ans  20 à 39 ans  40 à 59 ans  60 à 74 ans  75 ans et plus
# 1         75047        73097        81232        35341           25909
# 2         68777        65666        76307        36355           29131
# 3         34693        37071        49524        30300           27055
# 4         17250        16716        23062        13573            9897
# ..          ...          ...          ...          ...             ...
# 96       163750       167913       166438        58672           38943
# 97        59859        53921        59947        24720           13812
# 98        56422        52938        61543        26379           15478
# 99        47099        33399        20586         4500            1901
# 100      136316       119899       102585        34505           15467
#
#     Unnamed: 19
# 0         Total
# 1        290626
# 2        276236
# 3        178643
# 4         80498
# ..          ...
# 96       595716
# 97       212259
# 98       212760
# 99       107485
# 100      408772
#
# [101 rows x 20 columns]

# %%
def split_and_explode_population(df):
    """
    Sépare le dataframe source en hommes / femmes,
    puis transforme chaque sous-dataframe en format long
    """

    # --- 1. Séparation hommes / femmes ---
    df_homme = pd.concat([df.iloc[:, :2], df.iloc[:, 8:14]], axis=1)
    df_femme = pd.concat([df.iloc[:, :2], df.iloc[:, 14:20]], axis=1)

    return df_homme, df_femme

# %%
df_homme, df_femme = split_and_explode_population(df)

df_homme.head()
# Out:
#   Départements               Unnamed: 1      Hommes   Unnamed: 9  Unnamed: 10  \
# 0          NaN                      NaN  0 à 19 ans  20 à 39 ans  40 à 59 ans
# 1           01                      Ain       78672        74187        81771
# 2           02                    Aisne       72302        65638        76034
# 3           03                   Allier       36753        37614        48399
# 4           04  Alpes-de-Haute-Provence       18655        15991        22354
#
#    Unnamed: 11     Unnamed: 12 Unnamed: 13
# 0  60 à 74 ans  75 ans et plus       Total
# 1        33496           15625      283751
# 2        31402           16208      261584
# 3        25918           15787      164471
# 4        12322            6247       75569

# %%
import pandas as pd
import math

def explode_population_dataframe(df, sexe, annee, debug=True):
    """
    Transforme un dataframe large (par tranche d'âge)
    en dataframe long (1 ligne = 1 tranche)
    """
    lignes = []

    tranche_map = {
        2: "0 à 19 ans",
        3: "20 à 39 ans",
        4: "40 à 59 ans",
        5: "60 à 74 ans",
        6: "75 ans et plus"
    }

    if debug:
        print("=== DÉBUT TRAITEMENT DATAFRAME ===")
        print(f"Sexe traité : {sexe}")
        print(f"Nombre de lignes source : {len(df)}")
        print("-" * 50)

    for idx, row in df.iterrows():

        code_raw = row.iloc[0]
        nom_dept = row.iloc[1]

        # 🚫 SKIP ligne d'en-tête ou invalide
        if pd.isna(code_raw) or not str(code_raw).isdigit():
            if debug:
                print(f"[LIGNE {idx}] ⏭️ ignorée (ligne d'en-tête ou invalide)")
            continue

        code_dept = str(code_raw).zfill(2)

        if debug:
            print(f"[LIGNE {idx}] Département {code_dept} - {nom_dept}")

        for col_idx, tranche in tranche_map.items():
            population = row.iloc[col_idx]

            # sécurité supplémentaire
            if pd.isna(population):
                population = 0

            if debug:
                print(
                    f"  → Tranche: {tranche:<15} | "
                    f"Population: {population}"
                )

            lignes.append({
                "code_dept": code_dept,
                "nom_dept": nom_dept,
                "sexe": sexe,
                "tranche_age": tranche,
                "population": int(population),
                "annee": annee
            })

        if debug:
            print("-" * 50)

    df_result = pd.DataFrame(lignes)

    if debug:
        print("=== FIN TRAITEMENT ===")
        print(f"Nombre total de lignes générées : {len(df_result)}")
        print("Aperçu du résultat :")
        print(df_result.head())

    return df_result

# %%
explode_population_dataframe(df_homme, "H", 2007, False).head(1000)
# Out:
#     code_dept    nom_dept sexe     tranche_age  population  annee
# 0          01         Ain    H      0 à 19 ans       78672   2007
# 1          01         Ain    H     20 à 39 ans       74187   2007
# 2          01         Ain    H     40 à 59 ans       81771   2007
# 3          01         Ain    H     60 à 74 ans       33496   2007
# 4          01         Ain    H  75 ans et plus       15625   2007
# ..        ...         ...  ...             ...         ...    ...
# 485       974  La Réunion    H      0 à 19 ans      141874   2007
# 486       974  La Réunion    H     20 à 39 ans      107793   2007
# 487       974  La Réunion    H     40 à 59 ans       97687   2007
# 488       974  La Réunion    H     60 à 74 ans       29243   2007
# 489       974  La Réunion    H  75 ans et plus        8738   2007
#
# [490 rows x 6 columns]

# %%
explode_population_dataframe(df_femme, "F", 2007, False).head()
# Out:
#   code_dept nom_dept sexe     tranche_age  population  annee
# 0        01      Ain    F      0 à 19 ans       75047   2007
# 1        01      Ain    F     20 à 39 ans       73097   2007
# 2        01      Ain    F     40 à 59 ans       81232   2007
# 3        01      Ain    F     60 à 74 ans       35341   2007
# 4        01      Ain    F  75 ans et plus       25909   2007

# %%
import pandas as pd

df_population_all = []

for annee in range(2007, 2023):
    print(f"\n=== Traitement population {annee} ===")

    # 1. Lecture du fichier Excel
    df = pd.read_excel(f"./data/populations/pop-{annee}.xlsx")

    # Affichage rapide des premières lignes
    # print("Aperçu du fichier brut :")
    # print(df.head(2))
    
    # 2. Séparation hommes / femmes
    df_homme, df_femme = split_and_explode_population(df)

    # 3. Explosion (format long) avec debug activé
    df_homme_long = explode_population_dataframe(
        df_homme,
        sexe="H",
        annee=annee,
        debug=False
    )

    df_femme_long = explode_population_dataframe(
        df_femme,
        sexe="F",
        annee=annee,
        debug=False
    )

    # 4. Concaténer hommes + femmes pour cette année
    df_population_all.append(pd.concat([df_homme_long, df_femme_long], ignore_index=True))

# 5. Concaténation finale sur toutes les années
df_population = pd.concat(df_population_all, ignore_index=True)


print("\n=== Aperçu final population ===")
print(df_population.head(15))
print("\nNombre total de lignes :", len(df_population))
# Out:
# === Traitement population 2007 ===
#
# === Traitement population 2008 ===
#
# === Traitement population 2009 ===
#
# === Traitement population 2010 ===
#
# === Traitement population 2011 ===
#
# === Traitement population 2012 ===
#
# === Traitement population 2013 ===
#
# === Traitement population 2014 ===
#
# === Traitement population 2015 ===
#
# === Traitement population 2016 ===
#
# === Traitement population 2017 ===
#
# === Traitement population 2018 ===
#
# === Traitement population 2019 ===
#
# === Traitement population 2020 ===
#
# === Traitement population 2021 ===
#
# === Traitement population 2022 ===
#
# === Aperçu final population ===
#    code_dept nom_dept sexe     tranche_age  population  annee
# 0         01      Ain    H      0 à 19 ans       78672   2007
# 1         01      Ain    H     20 à 39 ans       74187   2007
# 2         01      Ain    H     40 à 59 ans       81771   2007
# 3         01      Ain    H     60 à 74 ans       33496   2007
# 4         01      Ain    H  75 ans et plus       15625   2007
# 5         02    Aisne    H      0 à 19 ans       72302   2007
# 6         02    Aisne    H     20 à 39 ans       65638   2007
# 7         02    Aisne    H     40 à 59 ans       76034   2007
# 8         02    Aisne    H     60 à 74 ans       31402   2007
# 9         02    Aisne    H  75 ans et plus       16208   2007
# 10        03   Allier    H      0 à 19 ans       36753   2007
# 11        03   Allier    H     20 à 39 ans       37614   2007
# 12        03   Allier    H     40 à 59 ans       48399   2007
# 13        03   Allier    H     60 à 74 ans       25918   2007
# 14        03   Allier    H  75 ans et plus       15787   2007
#
# Nombre total de lignes : 15770

# %%
df_population.to_excel("./exports/xlsx/population_2007_2023.xlsx", index=False)

# %%
from db import SessionLocal
from models import Sexe, TrancheAge

session = SessionLocal()

# %%
def seed_sexe(session):
    codes = ["ENSEMBLE", "H", "F"]
    for code in codes:
        if not session.query(Sexe).filter_by(code=code).first():
            session.add(Sexe(code=code))
    session.commit()

# %%
def seed_tranche_age(session):
    tranches = [
        (0, 19),
        (20, 39),
        (40, 59),
        (60, 74), 
        (75, None),
    ]

    for age_min, age_max in tranches:
        exists = session.query(TrancheAge).filter_by(
            age_min=age_min,
            age_max=age_max
        ).first()
        if not exists:
            session.add(
                TrancheAge(age_min=age_min, age_max=age_max)
            )
    session.commit()

# %%
def run():
    session = SessionLocal()
    try:
        seed_sexe(session)
        seed_tranche_age(session)
        session.commit()
    except:
        session.rollback()
        raise
    finally:
        session.close()

# %%
if __name__ == "__main__":
    run()
# Out:
# 2026-01-11 00:42:28,933 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-01-11 00:42:28,958 INFO sqlalchemy.engine.Engine SELECT sexe.id AS sexe_id, sexe.code AS sexe_code
# FROM sexe
# WHERE sexe.code = %(code_1)s
#  LIMIT %(param_1)s
# 2026-01-11 00:42:28,959 INFO sqlalchemy.engine.Engine [generated in 0.00148s] {'code_1': 'ENSEMBLE', 'param_1': 1}
# 2026-01-11 00:42:28,985 INFO sqlalchemy.engine.Engine SELECT sexe.id AS sexe_id, sexe.code AS sexe_code
# FROM sexe
# WHERE sexe.code = %(code_1)s
#  LIMIT %(param_1)s
# 2026-01-11 00:42:28,986 INFO sqlalchemy.engine.Engine [cached since 0.02824s ago] {'code_1': 'H', 'param_1': 1}
# 2026-01-11 00:42:28,988 INFO sqlalchemy.engine.Engine SELECT sexe.id AS sexe_id, sexe.code AS sexe_code
# FROM sexe
# WHERE sexe.code = %(code_1)s
#  LIMIT %(param_1)s
# 2026-01-11 00:42:28,989 INFO sqlalchemy.engine.Engine [cached since 0.03149s ago] {'code_1': 'F', 'param_1': 1}
# 2026-01-11 00:42:29,010 INFO sqlalchemy.engine.Engine INSERT INTO sexe (code) SELECT p0::VARCHAR FROM (VALUES (%(code__0)s, 0), (%(code__1)s, 1), (%(code__2)s, 2)) AS imp_sen(p0, sen_counter) ORDER BY sen_counter RETURNING sexe.id, sexe.id AS id__1
# 2026-01-11 00:42:29,011 INFO sqlalchemy.engine.Engine [generated in 0.00017s (insertmanyvalues) 1/1 (ordered)] {'code__0': 'ENSEMBLE', 'code__1': 'H', 'code__2': 'F'}
# 2026-01-11 00:42:29,041 INFO sqlalchemy.engine.Engine COMMIT
# 2026-01-11 00:42:29,047 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-01-11 00:42:29,049 INFO sqlalchemy.engine.Engine SELECT tranche_age.id AS tranche_age_id, tranche_age.age_min AS tranche_age_age_min, tranche_age.age_max AS tranche_age_age_max
# FROM tranche_age
# WHERE tranche_age.age_min = %(age_min_1)s AND tranche_age.age_max = %(age_max_1)s
#  LIMIT %(param_1)s
# 2026-01-11 00:42:29,050 INFO sqlalchemy.engine.Engine [generated in 0.00053s] {'age_min_1': 0, 'age_max_1': 19, 'param_1': 1}
# 2026-01-11 00:42:29,057 INFO sqlalchemy.engine.Engine SELECT tranche_age.id AS tranche_age_id, tranche_age.age_min AS tranche_age_age_min, tranche_age.age_max AS tranche_age_age_max
# FROM tranche_age
# WHERE tranche_age.age_min = %(age_min_1)s AND tranche_age.age_max = %(age_max_1)s
#  LIMIT %(param_1)s
# 2026-01-11 00:42:29,058 INFO sqlalchemy.engine.Engine [cached since 0.009139s ago] {'age_min_1': 20, 'age_max_1': 39, 'param_1': 1}
# 2026-01-11 00:42:29,063 INFO sqlalchemy.engine.Engine SELECT tranche_age.id AS tranche_age_id, tranche_age.age_min AS tranche_age_age_min, tranche_age.age_max AS tranche_age_age_max
# FROM tranche_age
# WHERE tranche_age.age_min = %(age_min_1)s AND tranche_age.age_max = %(age_max_1)s
#  LIMIT %(param_1)s
# 2026-01-11 00:42:29,063 INFO sqlalchemy.engine.Engine [cached since 0.01411s ago] {'age_min_1': 40, 'age_max_1': 59, 'param_1': 1}
# 2026-01-11 00:42:29,066 INFO sqlalchemy.engine.Engine SELECT tranche_age.id AS tranche_age_id, tranche_age.age_min AS tranche_age_age_min, tranche_age.age_max AS tranche_age_age_max
# FROM tranche_age
# WHERE tranche_age.age_min = %(age_min_1)s AND tranche_age.age_max = %(age_max_1)s
#  LIMIT %(param_1)s
# 2026-01-11 00:42:29,066 INFO sqlalchemy.engine.Engine [cached since 0.01692s ago] {'age_min_1': 60, 'age_max_1': 74, 'param_1': 1}
# 2026-01-11 00:42:29,069 INFO sqlalchemy.engine.Engine SELECT tranche_age.id AS tranche_age_id, tranche_age.age_min AS tranche_age_age_min, tranche_age.age_max AS tranche_age_age_max
# FROM tranche_age
# WHERE tranche_age.age_min = %(age_min_1)s AND tranche_age.age_max IS NULL
#  LIMIT %(param_1)s
# 2026-01-11 00:42:29,070 INFO sqlalchemy.engine.Engine [generated in 0.00108s] {'age_min_1': 75, 'param_1': 1}
# 2026-01-11 00:42:29,076 INFO sqlalchemy.engine.Engine INSERT INTO tranche_age (age_min, age_max) SELECT p0::INTEGER, p1::INTEGER FROM (VALUES (%(age_min__0)s, %(age_max__0)s, 0), (%(age_min__1)s, %(age_max__1)s, 1), (%(age_min__2)s, %(age_max__2)s, 2), (%(age_min__3)s, %(age_max__3)s, 3), (%(age_min__4)s, %(age_max__4)s, 4)) AS imp_sen(p0, p1, sen_counter) ORDER BY sen_counter RETURNING tranche_age.id, tranche_age.id AS id__1
# 2026-01-11 00:42:29,077 INFO sqlalchemy.engine.Engine [generated in 0.00013s (insertmanyvalues) 1/1 (ordered)] {'age_min__0': 0, 'age_max__0': 19, 'age_min__1': 20, 'age_max__1': 39, 'age_min__2': 40, 'age_max__2': 59, 'age_min__3': 60, 'age_max__3': 74, 'age_min__4': 75, 'age_max__4': None}
# 2026-01-11 00:42:29,081 INFO sqlalchemy.engine.Engine COMMIT

# %%
from sqlalchemy.orm import Session
import re
from models import PopulationDepartement, Departement

# %%
# Mapping direct tranche -> (age_min, age_max)
TRANCHES_AGE_MAP = {
    "0 à 19 ans": (0, 19),
    "20 à 39 ans": (20, 39),
    "40 à 59 ans": (40, 59),
    "60 à 74 ans": (60, 74),
    "75 ans et plus": (75, None),
}

def parse_tranche_age(tranche_str: str):
    """
    Retourne (age_min, age_max) à partir d'une chaîne de tranche connue.
    """
    return TRANCHES_AGE_MAP[tranche_str]

# %%
def inserer_population(df, session: Session):
    # Mapping direct des tranches d'âge
    TRANCHES_AGE_MAP = {
        "0 à 19 ans": (0, 19),
        "20 à 39 ans": (20, 39),
        "40 à 59 ans": (40, 59),
        "60 à 74 ans": (60, 74),
        "75 ans et plus": (75, None),
    }

    # Mapping des départements d'outre-mer
    DOM_CODES_MAP = {
        "971": "ZA",  # Guadeloupe
        "972": "ZB",  # Martinique
        "973": "ZC",  # Guyane
        "974": "ZD",  # La Réunion
    }

    # Récupération des objets existants
    departements = {d.code_dept: d for d in session.query(Departement).all()}
    sexes = {s.code: s for s in session.query(Sexe).all()}
    tranches = session.query(TrancheAge).all()
    tranches_map = {(t.age_min, t.age_max): t for t in tranches}

    # Précharger les populations existantes pour éviter doublons
    existing_keys = set(
        session.query(
            PopulationDepartement.departement_code,
            PopulationDepartement.sexe_id,
            PopulationDepartement.tranche_age_id,
            PopulationDepartement.annee
        ).all()
    )

    to_insert = []

    for _, row in df.iterrows():
        # ===== Normalisation du code département =====
        code_dept_raw = str(row["code_dept"]).strip()

        if code_dept_raw in DOM_CODES_MAP:
            code_dept_db = DOM_CODES_MAP[code_dept_raw]
        else:
            # Métropole : 01, 02, ..., 95
            code_dept_db = code_dept_raw.zfill(2)

        dept = departements.get(code_dept_db)
        sexe = sexes.get(str(row["sexe"]).strip())

        if not dept:
            print(f"⚠️ Département non trouvé pour la ligne: {row['code_dept']}")
            continue

        if not sexe:
            print(f"⚠️ Sexe non trouvé pour la ligne: {row['sexe']}")
            continue

        # ===== Tranche d'âge =====
        age_min, age_max = TRANCHES_AGE_MAP[row["tranche_age"]]
        tranche = tranches_map.get((age_min, age_max))
        if not tranche:
            print(f"⚠️ Tranche d'âge non trouvée pour: {row['tranche_age']}")
            continue

        # ===== Clé unique (anti-doublon) =====
        key = (dept.code_dept, sexe.id, tranche.id, row["annee"])
        if key in existing_keys:
            continue

        # ===== Création PopulationDepartement =====
        pop_dept = PopulationDepartement(
            departement_code=dept.code_dept,
            departement=dept,
            sexe_id=sexe.id,
            sexe=sexe,
            tranche_age_id=tranche.id,
            tranche_age=tranche,
            annee=row["annee"],
            population=row["population"]
        )

        to_insert.append(pop_dept)
        existing_keys.add(key)

    # ===== Insertion en base =====
    if to_insert:
        session.bulk_save_objects(to_insert)
        session.commit()
        print(f"✅ {len(to_insert)} populations insérées avec succès.")
    else:
        print("ℹ️ Aucune nouvelle population à insérer, tout est déjà présent.")

# %%
# Code département comme chaîne à 2 chiffres (01, 02, …)
df_population["code_dept"] = df_population["code_dept"].astype(str).str.zfill(2)

# Sexe propre
df_population["sexe"] = df_population["sexe"].str.strip()

# %%
inserer_population(df_population, session)
# Out:
# 2026-01-11 00:51:13,064 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-01-11 00:51:13,070 INFO sqlalchemy.engine.Engine SELECT departements.code_dept AS departements_code_dept, departements.nom_dept AS departements_nom_dept
# FROM departements
# 2026-01-11 00:51:13,072 INFO sqlalchemy.engine.Engine [cached since 2339s ago] {}
# 2026-01-11 00:51:13,105 INFO sqlalchemy.engine.Engine SELECT sexe.id AS sexe_id, sexe.code AS sexe_code
# FROM sexe
# 2026-01-11 00:51:13,105 INFO sqlalchemy.engine.Engine [cached since 2339s ago] {}
# 2026-01-11 00:51:13,107 INFO sqlalchemy.engine.Engine SELECT tranche_age.id AS tranche_age_id, tranche_age.age_min AS tranche_age_age_min, tranche_age.age_max AS tranche_age_age_max
# FROM tranche_age
# 2026-01-11 00:51:13,107 INFO sqlalchemy.engine.Engine [cached since 2339s ago] {}
# 2026-01-11 00:51:13,109 INFO sqlalchemy.engine.Engine SELECT population_departement.departement_code AS population_departement_departement_code, population_departement.sexe_id AS population_departement_sexe_id, population_departement.tranche_age_id AS population_departement_tranche_age_id, population_departement.annee AS population_departement_annee
# FROM population_departement
# 2026-01-11 00:51:13,110 INFO sqlalchemy.engine.Engine [cached since 2339s ago] {}
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# ⚠️ Département non trouvé pour la ligne: 976
# 2026-01-11 00:51:14,763 INFO sqlalchemy.engine.Engine INSERT INTO population_departement (departement_code, sexe_id, tranche_age_id, annee, population) VALUES (%(departement_code__0)s, %(sexe_id__0)s, %(tranche_age_id__0)s, %(annee__0)s, %(population__0)s), (%(departement_code__1)s, %(sexe_id__1)s, %(tr ... 108203 characters truncated ... rtement_code__999)s, %(sexe_id__999)s, %(tranche_age_id__999)s, %(annee__999)s, %(population__999)s)
# 2026-01-11 00:51:14,764 INFO sqlalchemy.engine.Engine [cached since 499.6s ago (insertmanyvalues) 1/16 (unordered)] {'annee__0': 2007, 'departement_code__0': '01', 'sexe_id__0': 2, 'population__0': 78672, 'tranche_age_id__0': 1, 'annee__1': 2007, 'departement_code__1': '01', 'sexe_id__1': 2, 'population__1': 74187, 'tranche_age_id__1': 2, 'annee__2': 2007, 'departement_code__2': '01', 'sexe_id__2': 2, 'population__2': 81771, 'tranche_age_id__2': 3, 'annee__3': 2007, 'departement_code__3': '01', 'sexe_id__3': 2, 'population__3': 33496, 'tranche_age_id__3': 4, 'annee__4': 2007, 'departement_code__4': '01', 'sexe_id__4': 2, 'population__4': 15625, 'tranche_age_id__4': 5, 'annee__5': 2007, 'departement_code__5': '02', 'sexe_id__5': 2, 'population__5': 72302, 'tranche_age_id__5': 1, 'annee__6': 2007, 'departement_code__6': '02', 'sexe_id__6': 2, 'population__6': 65638, 'tranche_age_id__6': 2, 'annee__7': 2007, 'departement_code__7': '02', 'sexe_id__7': 2, 'population__7': 76034, 'tranche_age_id__7': 3, 'annee__8': 2007, 'departement_code__8': '02', 'sexe_id__8': 2, 'population__8': 31402, 'tranche_age_id__8': 4, 'annee__9': 2007, 'departement_code__9': '02', 'sexe_id__9': 2, 'population__9': 16208, 'tranche_age_id__9': 5 ... 4900 parameters truncated ... 'annee__990': 2008, 'departement_code__990': '11', 'sexe_id__990': 2, 'population__990': 40033, 'tranche_age_id__990': 1, 'annee__991': 2008, 'departement_code__991': '11', 'sexe_id__991': 2, 'population__991': 37953, 'tranche_age_id__991': 2, 'annee__992': 2008, 'departement_code__992': '11', 'sexe_id__992': 2, 'population__992': 47262, 'tranche_age_id__992': 3, 'annee__993': 2008, 'departement_code__993': '11', 'sexe_id__993': 2, 'population__993': 27525, 'tranche_age_id__993': 4, 'annee__994': 2008, 'departement_code__994': '11', 'sexe_id__994': 2, 'population__994': 15847, 'tranche_age_id__994': 5, 'annee__995': 2008, 'departement_code__995': '12', 'sexe_id__995': 2, 'population__995': 29974, 'tranche_age_id__995': 1, 'annee__996': 2008, 'departement_code__996': '12', 'sexe_id__996': 2, 'population__996': 29443, 'tranche_age_id__996': 2, 'annee__997': 2008, 'departement_code__997': '12', 'sexe_id__997': 2, 'population__997': 39194, 'tranche_age_id__997': 3, 'annee__998': 2008, 'departement_code__998': '12', 'sexe_id__998': 2, 'population__998': 22181, 'tranche_age_id__998': 4, 'annee__999': 2008, 'departement_code__999': '12', 'sexe_id__999': 2, 'population__999': 14243, 'tranche_age_id__999': 5}
# 2026-01-11 00:51:14,815 INFO sqlalchemy.engine.Engine INSERT INTO population_departement (departement_code, sexe_id, tranche_age_id, annee, population) VALUES (%(departement_code__0)s, %(sexe_id__0)s, %(tranche_age_id__0)s, %(annee__0)s, %(population__0)s), (%(departement_code__1)s, %(sexe_id__1)s, %(tr ... 108203 characters truncated ... rtement_code__999)s, %(sexe_id__999)s, %(tranche_age_id__999)s, %(annee__999)s, %(population__999)s)
# 2026-01-11 00:51:14,816 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/16 (unordered)] {'annee__0': 2008, 'departement_code__0': '13', 'sexe_id__0': 2, 'population__0': 247275, 'tranche_age_id__0': 1, 'annee__1': 2008, 'departement_code__1': '13', 'sexe_id__1': 2, 'population__1': 248155, 'tranche_age_id__1': 2, 'annee__2': 2008, 'departement_code__2': '13', 'sexe_id__2': 2, 'population__2': 253639, 'tranche_age_id__2': 3, 'annee__3': 2008, 'departement_code__3': '
 'tranche_age_id__999': 5}
# 2026-01-11 00:51:15,371 INFO sqlalchemy.engine.Engine INSERT INTO population_departement (departement_code, sexe_id, tranche_age_id, annee, population) VALUES (%(departement_code__0)s, %(sexe_id__0)s, %(tranche_age_id__0)s, %(annee__0)s, %(population__0)s), (%(departement_code__1)s, %(sexe_id__1)s, %(tr ... 108203 characters truncated ... rtement_code__999)s, %(sexe_id__999)s, %(tranche_age_id__999)s, %(annee__999)s, %(population__999)s)
# 2026-01-11 00:51:15,372 INFO sqlalchemy.engine.Engine [insertmanyvalues 15/16 (unordered)] {'annee__0': 2021, 'departement_code__0': '76', 'sexe_id__0': 3, 'population__0': 148260, 'tranche_age_id__0': 1, 'annee__1': 2021, 'departement_code__1': '76', 'sexe_id__1': 3, 'population__1': 151305, 'tranche_age_id__1': 2, 'annee__2': 2021, 'departement_code__2': '76', 'sexe_id__2': 3, 'population__2': 159452, 'tranche_age_id__2': 3, 'annee__3': 2021, 'departement_code__3': '76', 'sexe_id__3': 3, 'population__3': 119854, 'tranche_age_id__3': 4, 'annee__4': 2021, 'departement_code__4': '76', 'sexe_id__4': 3, 'population__4': 72909, 'tranche_age_id__4': 5, 'annee__5': 2021, 'departement_code__5': '77', 'sexe_id__5': 3, 'population__5': 191293, 'tranche_age_id__5': 1, 'annee__6': 2021, 'departement_code__6': '77', 'sexe_id__6': 3, 'population__6': 186176, 'tranche_age_id__6': 2, 'annee__7': 2021, 'departement_code__7': '77', 'sexe_id__7': 3, 'population__7': 196105, 'tranche_age_id__7': 3, 'annee__8': 2021, 'departement_code__8': '77', 'sexe_id__8': 3, 'population__8': 108300, 'tranche_age_id__8': 4, 'annee__9': 2021, 'departement_code__9': '77', 'sexe_id__9': 3, 'population__9': 56174, 'tranche_age_id__9': 5 ... 4900 parameters truncated ... 'annee__990': 2022, 'departement_code__990': '86', 'sexe_id__990': 3, 'population__990': 49671, 'tranche_age_id__990': 1, 'annee__991': 2022, 'departement_code__991': '86', 'sexe_id__991': 3, 'population__991': 51695, 'tranche_age_id__991': 2, 'annee__992': 2022, 'departement_code__992': '86', 'sexe_id__992': 3, 'population__992': 55328, 'tranche_age_id__992': 3, 'annee__993': 2022, 'departement_code__993': '86', 'sexe_id__993': 3, 'population__993': 42268, 'tranche_age_id__993': 4, 'annee__994': 2022, 'departement_code__994': '86', 'sexe_id__994': 3, 'population__994': 28424, 'tranche_age_id__994': 5, 'annee__995': 2022, 'departement_code__995': '87', 'sexe_id__995': 3, 'population__995': 37881, 'tranche_age_id__995': 1, 'annee__996': 2022, 'departement_code__996': '87', 'sexe_id__996': 3, 'population__996': 40454, 'tranche_age_id__996': 2, 'annee__997': 2022, 'departement_code__997': '87', 'sexe_id__997': 3, 'population__997': 47546, 'tranche_age_id__997': 3, 'annee__998': 2022, 'departement_code__998': '87', 'sexe_id__998': 3, 'population__998': 39947, 'tranche_age_id__998': 4, 'annee__999': 2022, 'departement_code__999': '87', 'sexe_id__999': 3, 'population__999': 28195, 'tranche_age_id__999': 5}
# 2026-01-11 00:51:15,412 INFO sqlalchemy.engine.Engine INSERT INTO population_departement (departement_code, sexe_id, tranche_age_id, annee, population) VALUES (%(departement_code__0)s, %(sexe_id__0)s, %(tranche_age_id__0)s, %(annee__0)s, %(population__0)s), (%(departement_code__1)s, %(sexe_id__1)s, %(tr ... 3863 characters truncated ... (departement_code__39)s, %(sexe_id__39)s, %(tranche_age_id__39)s, %(annee__39)s, %(population__39)s)
# 2026-01-11 00:51:15,412 INFO sqlalchemy.engine.Engine [insertmanyvalues 16/16 (unordered)] {'annee__0': 2022, 'departement_code__0': '88', 'sexe_id__0': 3, 'population__0': 36900, 'tranche_age_id__0': 1, 'annee__1': 2022, 'departement_code__1': '88', 'sexe_id__1': 3, 'population__1': 34480, 'tranche_age_id__1': 2, 'annee__2': 2022, 'departement_code__2': '88', 'sexe_id__2': 3, 'population__2': 46757, 'tranche_age_id__2': 3, 'annee__3': 2022, 'departement_code__3': '88', 'sexe_id__3': 3, 'population__3': 39899, 'tranche_age_id__3': 4, 'annee__4': 2022, 'departement_code__4': '88', 'sexe_id__4': 3, 'population__4': 25533, 'tranche_age_id__4': 5, 'annee__5': 2022, 'departement_code__5': '89', 'sexe_id__5': 3, 'population__5': 35967, 'tranche_age_id__5': 1, 'annee__6': 2022, 'departement_code__6': '89', 'sexe_id__6': 3, 'population__6': 31638, 'tranche_age_id__6': 2, 'annee__7': 2022, 'departement_code__7': '89', 'sexe_id__7': 3, 'population__7': 43551, 'tranche_age_id__7': 3, 'annee__8': 2022, 'departement_code__8': '89', 'sexe_id__8': 3, 'population__8': 35785, 'tranche_age_id__8': 4, 'annee__9': 2022, 'departement_code__9': '89', 'sexe_id__9': 3, 'population__9': 22874, 'tranche_age_id__9': 5 ... 100 parameters truncated ... 'annee__30': 2022, 'departement_code__30': '94', 'sexe_id__30': 3, 'population__30': 174815, 'tranche_age_id__30': 1, 'annee__31': 2022, 'departement_code__31': '94', 'sexe_id__31': 3, 'population__31': 203817, 'tranche_age_id__31': 2, 'annee__32': 2022, 'departement_code__32': '94', 'sexe_id__32': 3, 'population__32': 189812, 'tranche_age_id__32': 3, 'annee__33': 2022, 'departement_code__33': '94', 'sexe_id__33': 3, 'population__33': 104202, 'tranche_age_id__33': 4, 'annee__34': 2022, 'departement_code__34': '94', 'sexe_id__34': 3, 'population__34': 64165, 'tranche_age_id__34': 5, 'annee__35': 2022, 'departement_code__35': '95', 'sexe_id__35': 3, 'population__35': 173387, 'tranche_age_id__35': 1, 'annee__36': 2022, 'departement_code__36': '95', 'sexe_id__36': 3, 'population__36': 169111, 'tranche_age_id__36': 2, 'annee__37': 2022, 'departement_code__37': '95', 'sexe_id__37': 3, 'population__37': 166264, 'tranche_age_id__37': 3, 'annee__38': 2022, 'departement_code__38': '95', 'sexe_id__38': 3, 'population__38': 92078, 'tranche_age_id__38': 4, 'annee__39': 2022, 'departement_code__39': '95', 'sexe_id__39': 3, 'population__39': 47303, 'tranche_age_id__39': 5}
# /tmp/ipykernel_91708/2940420868.py:88: SAWarning: Object of type <PopulationDepartement> not in session, add operation along 'Departement.populations' will not proceed
#   session.commit()
# 2026-01-11 00:51:16,156 INFO sqlalchemy.engine.Engine COMMIT
# ✅ 15040 populations insérées avec succès.
